# %%
import logging

import msmfcodesrc
from msmfcode.core.logging import log
from msmfcode.core.config import *
from msmfcode.execution.parallel import ParallelExecutor, ParallelEvaluationExecutor
from msmfcode.models.cann import DMSMF, FMSMF, Grid, SSSF
from msmfcode.evaluation.plot import plot_weight_distribution, plot_neuron_activity_fixed_attractors, \
    plot_neuron_activity_variable_attractors

# %%
# Configuration
PLOT_FILE_TYPE = 'pdf'
experiment_id = '3-2-b'
log.handlers[LogHandler.STREAM].setLevel(logging.INFO)
log.handlers[LogHandler.FILE].setLevel(logging.DETAIL)

# %% [markdown]
# ### Run a single evaluation

# %%
pe = ParallelEvaluationExecutor(experiment_id, FMSMF)

pe.run(reset_fields=True, cpu_cores_max=None)
pe.save_data(show_plots=False, save_plots=False)
# pe.cans[0].plot()
# plot_neuron_activity_variable_attractors_static(pe.cans[0], neuron_range=[0, 1, 2, 3, 4])

# %% [markdown]
# ### Run multiple evaluations

# %%
num_neurons_all = [50, 100, 200, 1000, 4000]
# n_min_all = [0, 5]

# for n_min in n_min_all:
for num_neurons in num_neurons_all:
    pe = ParallelEvaluationExecutor(experiment_id, FMSMF,
                                    parameters={
                                        'num_neurons': num_neurons,
                                        # 'nmin': n_min
                                    })
    pe.run(reset_fields=True, cpu_cores_max=None)
    pe.save_data(show_plots=False, save_plots=False)
# Out:
# > Starting experiment 3-2-b-11: Median error increase relative to number of fields
# > Evaluated parameter: f in  range(0.05, 1.01, 0.05)
# >> Starting evaluation run 1 with
# >> f = 0.05
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 19.73
# >> pos_error_std = 32.96
# >> pos_error_min = 0.00
# >> pos_error_max = 147.45
# >> pos_error_num_cat = 133.40
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 1.50
# >> num_fields_total = 75.00
# >> weighted_avg_activity = 5.95
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 2 with
# >> f = 0.1
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 4.35
# >> pos_error_std = 16.50
# >> pos_error_min = 0.00
# >> pos_error_max = 134.79
# >> pos_error_num_cat = 24.90
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 3.00
# >> num_fields_total = 150.00
# >> weighted_avg_activity = 14.93
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 3 with
# >> f = 0.15
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 1.26
# >> pos_error_std = 6.38
# >> pos_error_min = 0.00
# >> pos_error_max = 74.33
# >> pos_error_num_cat = 5.65
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 4.50
# >> num_fields_total = 225.00
# >> weighted_avg_activity = 20.93
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 4 with
# >> f = 0.2
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.58
# >> pos_error_std = 2.58
# >> pos_error_min = 0.00
# >> pos_error_max = 35.25
# >> pos_error_num_cat = 1.35
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 6.00
# >> num_fields_total = 300.00
# >> weighted_avg_activity = 29.84
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 5 with
# >> f = 0.25
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.36
# >> pos_error_std = 0.64
# >> pos_error_min = 0.00
# >> pos_error_max = 5.36
# >> pos_error_num_cat = 0.35
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 7.50
# >> num_fields_total = 375.00
# >> weighted_avg_activity = 35.84
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 6 with
# >> f = 0.3
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.33
# >> pos_error_std = 0.69
# >> pos_error_min = 0.00
# >> pos_error_max = 8.28
# >> pos_error_num_cat = 0.15
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 9.00
# >> num_fields_total = 450.00
# >> weighted_avg_activity = 44.78
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 7 with
# >> f = 0.35
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.28
# >> pos_error_std = 0.41
# >> pos_error_min = 0.00
# >> pos_error_max = 3.88
# >> pos_error_num_cat = 0.05
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 10.50
# >> num_fields_total = 525.00
# >> weighted_avg_activity = 50.74
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 8 with
# >> f = 0.4
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.15
# >> pos_error_std = 0.25
# >> pos_error_min = 0.00
# >> pos_error_max = 1.05
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 12.00
# >> num_fields_total = 600.00
# >> weighted_avg_activity = 59.58
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 9 with
# >> f = 0.45
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.23
# >> pos_error_std = 0.27
# >> pos_error_min = 0.00
# >> pos_error_max = 1.18
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 13.50
# >> num_fields_total = 675.00
# >> weighted_avg_activity = 65.62
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 10 with
# >> f = 0.5
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.24
# >> pos_error_std = 0.79
# >> pos_error_min = 0.00
# >> pos_error_max = 8.95
# >> pos_error_num_cat = 0.10
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 15.00
# >> num_fields_total = 750.00
# >> weighted_avg_activity = 74.56
# >> Run-time = 0:00:01 seconds
# >> Total time left = 0:00:10 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 11 with
# >> f = 0.55
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.27
# >> pos_error_std = 0.28
# >> pos_error_min = 0.00
# >> pos_error_max = 1.10
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 16.50
# >> num_fields_total = 825.00
# >> weighted_avg_activity = 80.52
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 12 with
# >> f = 0.6
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.23
# >> pos_error_std = 0.27
# >> pos_error_min = 0.00
# >> pos_error_max = 1.05
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 18.00
# >> num_fields_total = 900.00
# >> weighted_avg_activity = 89.46
# >> Run-time = 0:00:01 seconds
# >> Total time left = 0:00:08 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 13 with
# >> f = 0.65
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.21
# >> pos_error_std = 0.26
# >> pos_error_min = 0.00
# >> pos_error_max = 1.05
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 19.50
# >> num_fields_total = 975.00
# >> weighted_avg_activity = 95.42
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 14 with
# >> f = 0.7
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.20
# >> pos_error_std = 0.26
# >> pos_error_min = 0.00
# >> pos_error_max = 1.00
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 21.00
# >> num_fields_total = 1050.00
# >> weighted_avg_activity = 104.35
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 15 with
# >> f = 0.75
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.20
# >> pos_error_std = 0.27
# >> pos_error_min = 0.00
# >> pos_error_max = 1.08
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 22.50
# >> num_fields_total = 1125.00
# >> weighted_avg_activity = 110.31
# >> Run-time = 0:00:01 seconds
# >> Total time left = 0:00:05 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 16 with
# >> f = 0.8
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.16
# >> pos_error_std = 0.24
# >> pos_error_min = 0.00
# >> pos_error_max = 1.00
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 24.00
# >> num_fields_total = 1200.00
# >> weighted_avg_activity = 119.05
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 17 with
# >> f = 0.85
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.20
# >> pos_error_std = 0.26
# >> pos_error_min = 0.00
# >> pos_error_max = 1.03
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 25.50
# >> num_fields_total = 1275.00
# >> weighted_avg_activity = 125.20
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 18 with
# >> f = 0.9
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.20
# >> pos_error_std = 0.26
# >> pos_error_min = 0.00
# >> pos_error_max = 1.03
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 27.00
# >> num_fields_total = 1350.00
# >> weighted_avg_activity = 134.13
# >> Run-time = 0:00:01 seconds
# >> Total time left = 0:00:02 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 19 with
# >> f = 0.95
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.19
# >> pos_error_std = 0.26
# >> pos_error_min = 0.00
# >> pos_error_max = 1.00
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 28.50
# >> num_fields_total = 1425.00
# >> weighted_avg_activity = 140.08
# >> Run-time = 0:00:01 seconds
# >> Total time left = 0:00:01 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 20 with
# >> f = 1.0
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.19
# >> pos_error_std = 0.26
# >> pos_error_min = 0.00
# >> pos_error_max = 1.00
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 30.00
# >> num_fields_total = 1500.00
# >> weighted_avg_activity = 149.01
# >> Run-time = 0:00:00 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# > Finished experiment 3-2-b-11 in 19 seconds.
# > Starting experiment 3-2-b-12: Median error increase relative to number of fields
# > Evaluated parameter: f in  range(0.05, 1.01, 0.05)
# >> Starting evaluation run 1 with
# >> f = 0.05
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 1.80
# >> pos_error_std = 7.49
# >> pos_error_min = 0.00
# >> pos_error_max = 71.93
# >> pos_error_num_cat = 8.25
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 1.50
# >> num_fields_total = 150.00
# >> weighted_avg_activity = 14.94
# >> Run-time = 0:00:05 seconds
# >> Total time left = 0:01:35 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 2 with
# >> f = 0.1
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.38
# >> pos_error_std = 0.65
# >> pos_error_min = 0.00
# >> pos_error_max = 7.38
# >> pos_error_num_cat = 0.10
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 3.00
# >> num_fields_total = 300.00
# >> weighted_avg_activity = 29.85
# >> Run-time = 0:00:05 seconds
# >> Total time left = 0:01:30 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 3 with
# >> f = 0.15
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.29
# >> pos_error_std = 0.27
# >> pos_error_min = 0.00
# >> pos_error_max = 1.08
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 4.50
# >> num_fields_total = 450.00
# >> weighted_avg_activity = 44.79
# >> Run-time = 0:00:06 seconds
# >> Total time left = 0:01:42 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 4 with
# >> f = 0.2
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.10
# >> pos_error_std = 0.21
# >> pos_error_min = 0.00
# >> pos_error_max = 0.94
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 6.00
# >> num_fields_total = 600.00
# >> weighted_avg_activity = 59.58
# >> Run-time = 0:00:07 seconds
# >> Total time left = 0:01:52 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 5 with
# >> f = 0.25
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.16
# >> pos_error_std = 0.22
# >> pos_error_min = 0.00
# >> pos_error_max = 0.94
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 7.50
# >> num_fields_total = 750.00
# >> weighted_avg_activity = 74.57
# >> Run-time = 0:00:07 seconds
# >> Total time left = 0:01:45 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 6 with
# >> f = 0.3
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.18
# >> pos_error_std = 0.25
# >> pos_error_min = 0.00
# >> pos_error_max = 1.00
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 9.00
# >> num_fields_total = 900.00
# >> weighted_avg_activity = 89.46
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:01:52 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 7 with
# >> f = 0.35
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.16
# >> pos_error_std = 0.24
# >> pos_error_min = 0.00
# >> pos_error_max = 0.98
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 10.50
# >> num_fields_total = 1050.00
# >> weighted_avg_activity = 104.36
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:01:44 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 8 with
# >> f = 0.4
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.10
# >> pos_error_std = 0.20
# >> pos_error_min = 0.00
# >> pos_error_max = 0.73
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 12.00
# >> num_fields_total = 1200.00
# >> weighted_avg_activity = 119.06
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:01:36 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 9 with
# >> f = 0.45
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.14
# >> pos_error_std = 0.22
# >> pos_error_min = 0.00
# >> pos_error_max = 0.80
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 13.50
# >> num_fields_total = 1350.00
# >> weighted_avg_activity = 134.14
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:01:28 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 10 with
# >> f = 0.5
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.12
# >> pos_error_std = 0.21
# >> pos_error_min = 0.00
# >> pos_error_max = 0.63
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 15.00
# >> num_fields_total = 1500.00
# >> weighted_avg_activity = 149.03
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:01:20 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 11 with
# >> f = 0.55
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.14
# >> pos_error_std = 0.22
# >> pos_error_min = 0.00
# >> pos_error_max = 0.75
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 16.50
# >> num_fields_total = 1650.00
# >> weighted_avg_activity = 163.93
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:01:12 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 12 with
# >> f = 0.6
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.10
# >> pos_error_std = 0.20
# >> pos_error_min = 0.00
# >> pos_error_max = 0.65
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 18.00
# >> num_fields_total = 1800.00
# >> weighted_avg_activity = 178.81
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:01:04 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 13 with
# >> f = 0.65
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.12
# >> pos_error_std = 0.22
# >> pos_error_min = 0.00
# >> pos_error_max = 0.68
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 19.50
# >> num_fields_total = 1950.00
# >> weighted_avg_activity = 193.71
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:00:56 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 14 with
# >> f = 0.7
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.15
# >> pos_error_std = 0.23
# >> pos_error_min = 0.00
# >> pos_error_max = 0.83
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 21.00
# >> num_fields_total = 2100.00
# >> weighted_avg_activity = 208.60
# >> Run-time = 0:00:09 seconds
# >> Total time left = 0:00:54 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 15 with
# >> f = 0.75
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.12
# >> pos_error_std = 0.22
# >> pos_error_min = 0.00
# >> pos_error_max = 0.75
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 22.50
# >> num_fields_total = 2250.00
# >> weighted_avg_activity = 223.49
# >> Run-time = 0:00:09 seconds
# >> Total time left = 0:00:45 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 16 with
# >> f = 0.8
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.11
# >> pos_error_std = 0.21
# >> pos_error_min = 0.00
# >> pos_error_max = 0.65
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 24.00
# >> num_fields_total = 2400.00
# >> weighted_avg_activity = 238.41
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:00:32 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 17 with
# >> f = 0.85
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.12
# >> pos_error_std = 0.22
# >> pos_error_min = 0.00
# >> pos_error_max = 0.63
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 25.50
# >> num_fields_total = 2550.00
# >> weighted_avg_activity = 253.27
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:00:24 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 18 with
# >> f = 0.9
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.13
# >> pos_error_std = 0.22
# >> pos_error_min = 0.00
# >> pos_error_max = 0.73
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 27.00
# >> num_fields_total = 2700.00
# >> weighted_avg_activity = 268.16
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:00:16 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 19 with
# >> f = 0.95
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.13
# >> pos_error_std = 0.22
# >> pos_error_min = 0.00
# >> pos_error_max = 0.80
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 28.50
# >> num_fields_total = 2850.00
# >> weighted_avg_activity = 283.05
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:00:08 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 20 with
# >> f = 1.0
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.12
# >> pos_error_std = 0.21
# >> pos_error_min = 0.00
# >> pos_error_max = 0.73
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 30.00
# >> num_fields_total = 3000.00
# >> weighted_avg_activity = 297.95
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# > Finished experiment 3-2-b-12 in 162 seconds.
# > Starting experiment 3-2-b-13: Median error increase relative to number of fields
# > Evaluated parameter: f in  range(0.05, 1.01, 0.05)
# >> Starting evaluation run 1 with
# >> f = 0.05
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.35
# >> pos_error_std = 0.39
# >> pos_error_min = 0.00
# >> pos_error_max = 1.58
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 1.50
# >> num_fields_total = 300.00
# >> weighted_avg_activity = 29.87
# >> Run-time = 0:00:08 seconds
# >> Total time left = 0:02:32 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 2 with
# >> f = 0.1
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.08
# >> pos_error_std = 0.18
# >> pos_error_min = 0.00
# >> pos_error_max = 0.73
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 3.00
# >> num_fields_total = 600.00
# >> weighted_avg_activity = 59.60
# >> Run-time = 0:00:10 seconds
# >> Total time left = 0:03:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 3 with
# >> f = 0.15
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.16
# >> pos_error_std = 0.24
# >> pos_error_min = 0.00
# >> pos_error_max = 0.78
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 4.50
# >> num_fields_total = 900.00
# >> weighted_avg_activity = 89.49
# >> Run-time = 0:00:11 seconds
# >> Total time left = 0:03:07 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 4 with
# >> f = 0.2
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.06
# >> pos_error_std = 0.16
# >> pos_error_min = 0.00
# >> pos_error_max = 0.58
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 6.00
# >> num_fields_total = 1200.00
# >> weighted_avg_activity = 119.08
# >> Run-time = 0:00:12 seconds
# >> Total time left = 0:03:12 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 5 with
# >> f = 0.25
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.08
# >> pos_error_std = 0.18
# >> pos_error_min = 0.00
# >> pos_error_max = 0.55
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 7.50
# >> num_fields_total = 1500.00
# >> weighted_avg_activity = 149.06
# >> Run-time = 0:00:12 seconds
# >> Total time left = 0:03:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 6 with
# >> f = 0.3
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.05
# >> pos_error_std = 0.15
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 9.00
# >> num_fields_total = 1800.00
# >> weighted_avg_activity = 178.83
# >> Run-time = 0:00:11 seconds
# >> Total time left = 0:02:34 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 7 with
# >> f = 0.35
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.11
# >> pos_error_std = 0.20
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 10.50
# >> num_fields_total = 2100.00
# >> weighted_avg_activity = 208.62
# >> Run-time = 0:00:12 seconds
# >> Total time left = 0:02:36 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 8 with
# >> f = 0.4
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.05
# >> pos_error_std = 0.15
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 12.00
# >> num_fields_total = 2400.00
# >> weighted_avg_activity = 238.41
# >> Run-time = 0:00:10 seconds
# >> Total time left = 0:02:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 9 with
# >> f = 0.45
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.07
# >> pos_error_std = 0.18
# >> pos_error_min = 0.00
# >> pos_error_max = 0.60
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 13.50
# >> num_fields_total = 2700.00
# >> weighted_avg_activity = 268.18
# >> Run-time = 0:00:10 seconds
# >> Total time left = 0:01:50 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 10 with
# >> f = 0.5
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.06
# >> pos_error_std = 0.16
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 15.00
# >> num_fields_total = 3000.00
# >> weighted_avg_activity = 297.98
# >> Run-time = 0:00:11 seconds
# >> Total time left = 0:01:50 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 11 with
# >> f = 0.55
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.08
# >> pos_error_std = 0.18
# >> pos_error_min = 0.00
# >> pos_error_max = 0.53
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 16.50
# >> num_fields_total = 3300.00
# >> weighted_avg_activity = 327.77
# >> Run-time = 0:00:11 seconds
# >> Total time left = 0:01:39 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 12 with
# >> f = 0.6
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.05
# >> pos_error_std = 0.15
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 18.00
# >> num_fields_total = 3600.00
# >> weighted_avg_activity = 357.54
# >> Run-time = 0:00:13 seconds
# >> Total time left = 0:01:44 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 13 with
# >> f = 0.65
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.07
# >> pos_error_std = 0.17
# >> pos_error_min = 0.00
# >> pos_error_max = 0.53
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 19.50
# >> num_fields_total = 3900.00
# >> weighted_avg_activity = 387.32
# >> Run-time = 0:00:12 seconds
# >> Total time left = 0:01:24 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 14 with
# >> f = 0.7
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.05
# >> pos_error_std = 0.15
# >> pos_error_min = 0.00
# >> pos_error_max = 0.55
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 21.00
# >> num_fields_total = 4200.00
# >> weighted_avg_activity = 417.10
# >> Run-time = 0:00:12 seconds
# >> Total time left = 0:01:12 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 15 with
# >> f = 0.75
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.07
# >> pos_error_std = 0.18
# >> pos_error_min = 0.00
# >> pos_error_max = 0.53
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 22.50
# >> num_fields_total = 4500.00
# >> weighted_avg_activity = 446.88
# >> Run-time = 0:00:12 seconds
# >> Total time left = 0:01:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 16 with
# >> f = 0.8
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.06
# >> pos_error_std = 0.16
# >> pos_error_min = 0.00
# >> pos_error_max = 0.53
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 24.00
# >> num_fields_total = 4800.00
# >> weighted_avg_activity = 476.68
# >> Run-time = 0:00:12 seconds
# >> Total time left = 0:00:48 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 17 with
# >> f = 0.85
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.07
# >> pos_error_std = 0.17
# >> pos_error_min = 0.00
# >> pos_error_max = 0.58
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 25.50
# >> num_fields_total = 5100.00
# >> weighted_avg_activity = 506.45
# >> Run-time = 0:00:11 seconds
# >> Total time left = 0:00:33 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 18 with
# >> f = 0.9
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.06
# >> pos_error_std = 0.16
# >> pos_error_min = 0.00
# >> pos_error_max = 0.65
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 27.00
# >> num_fields_total = 5400.00
# >> weighted_avg_activity = 536.23
# >> Run-time = 0:00:12 seconds
# >> Total time left = 0:00:24 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 19 with
# >> f = 0.95
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.07
# >> pos_error_std = 0.17
# >> pos_error_min = 0.00
# >> pos_error_max = 0.70
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 28.50
# >> num_fields_total = 5700.00
# >> weighted_avg_activity = 566.01
# >> Run-time = 0:00:12 seconds
# >> Total time left = 0:00:12 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 20 with
# >> f = 1.0
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.06
# >> pos_error_std = 0.17
# >> pos_error_min = 0.00
# >> pos_error_max = 0.58
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 30.00
# >> num_fields_total = 6000.00
# >> weighted_avg_activity = 595.78
# >> Run-time = 0:00:12 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# > Finished experiment 3-2-b-13 in 235 seconds.
# > Starting experiment 3-2-b-14: Median error increase relative to number of fields
# > Evaluated parameter: f in  range(0.05, 1.01, 0.05)
# >> Starting evaluation run 1 with
# >> f = 0.05
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.02
# >> pos_error_std = 0.10
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 1.50
# >> num_fields_total = 1500.00
# >> weighted_avg_activity = 149.21
# >> Run-time = 0:00:15 seconds
# >> Total time left = 0:04:45 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 2 with
# >> f = 0.1
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.01
# >> pos_error_std = 0.07
# >> pos_error_min = 0.00
# >> pos_error_max = 0.53
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 3.00
# >> num_fields_total = 3000.00
# >> weighted_avg_activity = 298.12
# >> Run-time = 0:00:28 seconds
# >> Total time left = 0:08:24 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 3 with
# >> f = 0.15
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.02
# >> pos_error_std = 0.09
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 4.50
# >> num_fields_total = 4500.00
# >> weighted_avg_activity = 447.06
# >> Run-time = 0:00:29 seconds
# >> Total time left = 0:08:13 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 4 with
# >> f = 0.2
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.04
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 6.00
# >> num_fields_total = 6000.00
# >> weighted_avg_activity = 596.04
# >> Run-time = 0:00:31 seconds
# >> Total time left = 0:08:16 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 5 with
# >> f = 0.25
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.01
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.55
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 7.50
# >> num_fields_total = 7500.00
# >> weighted_avg_activity = 744.88
# >> Run-time = 0:00:34 seconds
# >> Total time left = 0:08:30 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 6 with
# >> f = 0.3
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.04
# >> pos_error_min = 0.00
# >> pos_error_max = 0.53
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 9.00
# >> num_fields_total = 9000.00
# >> weighted_avg_activity = 893.80
# >> Run-time = 0:00:33 seconds
# >> Total time left = 0:07:42 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 7 with
# >> f = 0.35
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 10.50
# >> num_fields_total = 10500.00
# >> weighted_avg_activity = 1042.68
# >> Run-time = 0:00:35 seconds
# >> Total time left = 0:07:35 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 8 with
# >> f = 0.4
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.04
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 12.00
# >> num_fields_total = 12000.00
# >> weighted_avg_activity = 1191.63
# >> Run-time = 0:00:38 seconds
# >> Total time left = 0:07:36 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 9 with
# >> f = 0.45
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.63
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 13.50
# >> num_fields_total = 13500.00
# ...
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.06
# >> pos_error_min = 0.00
# >> pos_error_max = 0.83
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 27.00
# >> num_fields_total = 27000.00
# >> weighted_avg_activity = 2680.78
# >> Run-time = 0:00:53 seconds
# >> Total time left = 0:01:46 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 19 with
# >> f = 0.95
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.01
# >> pos_error_std = 0.06
# >> pos_error_min = 0.00
# >> pos_error_max = 0.88
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 28.50
# >> num_fields_total = 28500.00
# >> weighted_avg_activity = 2829.69
# >> Run-time = 0:00:53 seconds
# >> Total time left = 0:00:53 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 20 with
# >> f = 1.0
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.01
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.70
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 30.00
# >> num_fields_total = 30000.00
# >> weighted_avg_activity = 2978.61
# >> Run-time = 0:00:55 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# > Finished experiment 3-2-b-14 in 810 seconds.
# > Starting experiment 3-2-b-15: Median error increase relative to number of fields
# > Evaluated parameter: f in  range(0.05, 1.01, 0.05)
# >> Starting evaluation run 1 with
# >> f = 0.05
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.04
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 1.50
# >> num_fields_total = 6000.00
# >> weighted_avg_activity = 596.59
# >> Run-time = 0:00:36 seconds
# >> Total time left = 0:11:24 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 2 with
# >> f = 0.1
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.04
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 3.00
# >> num_fields_total = 12000.00
# >> weighted_avg_activity = 1192.24
# >> Run-time = 0:00:40 seconds
# >> Total time left = 0:12:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 3 with
# >> f = 0.15
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.04
# >> pos_error_min = 0.00
# >> pos_error_max = 0.50
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 4.50
# >> num_fields_total = 18000.00
# >> weighted_avg_activity = 1787.91
# >> Run-time = 0:00:43 seconds
# >> Total time left = 0:12:11 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 4 with
# >> f = 0.2
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.04
# >> pos_error_min = 0.00
# >> pos_error_max = 0.58
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 6.00
# >> num_fields_total = 24000.00
# >> weighted_avg_activity = 2383.57
# >> Run-time = 0:00:47 seconds
# >> Total time left = 0:12:32 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 5 with
# >> f = 0.25
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.04
# >> pos_error_min = 0.00
# >> pos_error_max = 0.68
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 7.50
# >> num_fields_total = 30000.00
# >> weighted_avg_activity = 2979.22
# >> Run-time = 0:00:52 seconds
# >> Total time left = 0:13:00 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 6 with
# >> f = 0.3
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.75
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 9.00
# >> num_fields_total = 36000.00
# >> weighted_avg_activity = 3574.89
# >> Run-time = 0:00:57 seconds
# >> Total time left = 0:13:18 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 7 with
# >> f = 0.35
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.83
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 10.50
# >> num_fields_total = 42000.00
# >> weighted_avg_activity = 4170.54
# >> Run-time = 0:01:02 seconds
# >> Total time left = 0:13:26 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 8 with
# >> f = 0.4
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.83
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 12.00
# >> num_fields_total = 48000.00
# >> weighted_avg_activity = 4766.20
# >> Run-time = 0:01:07 seconds
# >> Total time left = 0:13:24 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 9 with
# >> f = 0.45
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.83
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 13.50
# >> num_fields_total = 54000.00
# >> weighted_avg_activity = 5361.86
# >> Run-time = 0:01:14 seconds
# >> Total time left = 0:13:34 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 10 with
# >> f = 0.5
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.95
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 15.00
# >> num_fields_total = 60000.00
# >> weighted_avg_activity = 5957.52
# >> Run-time = 0:01:21 seconds
# >> Total time left = 0:13:30 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 11 with
# >> f = 0.55
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.85
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 16.50
# >> num_fields_total = 66000.00
# >> weighted_avg_activity = 6553.18
# >> Run-time = 0:01:22 seconds
# >> Total time left = 0:12:18 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 12 with
# >> f = 0.6
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.95
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 18.00
# >> num_fields_total = 72000.00
# >> weighted_avg_activity = 7148.84
# >> Run-time = 0:01:29 seconds
# >> Total time left = 0:11:52 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 13 with
# >> f = 0.65
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.06
# >> pos_error_min = 0.00
# >> pos_error_max = 1.00
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 19.50
# >> num_fields_total = 78000.00
# >> weighted_avg_activity = 7744.50
# >> Run-time = 0:01:34 seconds
# >> Total time left = 0:10:58 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 14 with
# >> f = 0.7
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.06
# >> pos_error_min = 0.00
# >> pos_error_max = 1.00
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 21.00
# >> num_fields_total = 84000.00
# >> weighted_avg_activity = 8340.16
# >> Run-time = 0:01:39 seconds
# >> Total time left = 0:09:54 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 15 with
# >> f = 0.75
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.06
# >> pos_error_min = 0.00
# >> pos_error_max = 0.98
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 22.50
# >> num_fields_total = 90000.00
# >> weighted_avg_activity = 8935.82
# >> Run-time = 0:01:47 seconds
# >> Total time left = 0:08:55 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 16 with
# >> f = 0.8
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.06
# >> pos_error_min = 0.00
# >> pos_error_max = 1.00
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 24.00
# >> num_fields_total = 96000.00
# >> weighted_avg_activity = 9531.48
# >> Run-time = 0:01:47 seconds
# >> Total time left = 0:07:08 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 17 with
# >> f = 0.85
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.05
# >> pos_error_min = 0.00
# >> pos_error_max = 0.95
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 25.50
# >> num_fields_total = 102000.00
# >> weighted_avg_activity = 10127.14
# >> Run-time = 0:01:58 seconds
# >> Total time left = 0:05:54 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 18 with
# >> f = 0.9
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.06
# >> pos_error_min = 0.00
# >> pos_error_max = 1.00
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 27.00
# >> num_fields_total = 108000.00
# >> weighted_avg_activity = 10722.80
# >> Run-time = 0:02:03 seconds
# >> Total time left = 0:04:06 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 19 with
# >> f = 0.95
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.06
# >> pos_error_min = 0.00
# >> pos_error_max = 1.00
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 28.50
# >> num_fields_total = 114000.00
# >> weighted_avg_activity = 11318.46
# >> Run-time = 0:02:11 seconds
# >> Total time left = 0:02:11 seconds
# -------------------------------------------------------------------------------------
# >> Starting evaluation run 20 with
# >> f = 1.0
# >> Starting batch run [1/1]
# >> Started all CAN simulations
# >> Finished all CAN simulations
# -------------------------------------------------------------------------------------
# >> Metrics after 20 runs:
# >> pos_error_mean = 0.00
# >> pos_error_std = 0.06
# >> pos_error_min = 0.00
# >> pos_error_max = 0.98
# >> pos_error_num_cat = 0.00
# >> mean_field_activity = 0.03
# >> perc_correct_fields = 1.00
# >> avg_num_fields_per_neuron = 30.00
# >> num_fields_total = 120000.00
# >> weighted_avg_activity = 11914.12
# >> Run-time = 0:02:19 seconds
# >> Total time left = 0:00:00 seconds
# -------------------------------------------------------------------------------------
# > Finished experiment 3-2-b-15 in 1657 seconds.
